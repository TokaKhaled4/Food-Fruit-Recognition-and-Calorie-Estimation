# %% [markdown]
# # **Food/Fruit Recognition and Calorie Estimation**
# ## **Part C Fruit Classification**

# %% [markdown]
# ## **Imports**

# %%
import os
import time
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import (
    ResNet50,
    EfficientNetB4,
    ConvNeXtTiny
)
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Configuration**

# %%
AUTOTUNE = tf.data.AUTOTUNE

class Config:
    TRAIN_DIR = "/kaggle/input/vision-data/Project Data/Fruit/Train"
    VAL_DIR   = "/kaggle/input/vision-data/Project Data/Fruit/Validation"

    IMG_SIZE = 350
    BATCH_SIZE = 14
    EPOCHS = 10
    LR = 1e-4

# %% [markdown]
# ## **DataLoaders**

# %%
def load_image_paths(root_dir):
    image_paths = []
    labels = []
    class_names = sorted(os.listdir(root_dir))

    class_to_idx = {cls: i for i, cls in enumerate(class_names)}

    for cls in class_names:
        img_dir = os.path.join(root_dir, cls, "Images")
        if not os.path.isdir(img_dir):
            continue

        for f in os.listdir(img_dir):
            if f.lower().endswith((".jpg", ".png", ".jpeg")):
                image_paths.append(os.path.join(img_dir, f))
                labels.append(class_to_idx[cls])

    return image_paths, labels, class_names


train_paths, train_labels, class_names = load_image_paths(Config.TRAIN_DIR)
val_paths, val_labels, _ = load_image_paths(Config.VAL_DIR)

NUM_CLASSES = len(class_names)

# %% [markdown]
# ## **Preprocessing**

# %%
MEAN = tf.constant([0.485, 0.456, 0.406])
STD  = tf.constant([0.229, 0.224, 0.225])

def load_and_preprocess(path, label, augment=False):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (Config.IMG_SIZE, Config.IMG_SIZE))
    img = tf.cast(img, tf.float32) / 255.0

    if augment:
        img = tf.image.random_flip_left_right(img)
        img = tf.image.random_flip_up_down(img)
        img = tf.image.random_brightness(img, 0.1)
        img = tf.image.random_contrast(img, 0.7, 1.3)
        img = tf.image.rot90(img, tf.random.uniform([], 0, 4, tf.int32))

    img = (img - MEAN) / STD
    return img, label



AUTOTUNE = tf.data.AUTOTUNE

train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_ds = train_ds.shuffle(1000)
train_ds = train_ds.map(
    lambda x, y: load_and_preprocess(x, y, augment=True),
    num_parallel_calls=AUTOTUNE
)
train_ds = train_ds.batch(Config.BATCH_SIZE).prefetch(AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
val_ds = val_ds.map(
    lambda x, y: load_and_preprocess(x, y, augment=False),
    num_parallel_calls=AUTOTUNE
)
val_ds = val_ds.batch(Config.BATCH_SIZE).prefetch(AUTOTUNE)

# %% [markdown]
# ## **ResNet50**

# %%
base = ResNet50(
    weights="imagenet",
    include_top=False,
    input_shape=(Config.IMG_SIZE, Config.IMG_SIZE, 3)
)

inputs = layers.Input((Config.IMG_SIZE, Config.IMG_SIZE, 3))
x = base(inputs, training=True)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(512, activation="relu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = models.Model(inputs, outputs)



model.compile(
    optimizer=tf.keras.optimizers.Adam(Config.LR),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

start_time = time.time()

model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=Config.EPOCHS
)
end_time = time.time()

model.save("ResNet50.keras")

# 5. Calculate and Print the Training Time
total_training_time_seconds = end_time - start_time
minutes = int(total_training_time_seconds // 60)
seconds = int(total_training_time_seconds % 60)
print("--------------------------------------------------")
print(f"✅ Training Finished. Model saved to ResNet50.keras")
print(f"⏱️ Total Training Time: {minutes} minutes and {seconds} seconds ({total_training_time_seconds:.2f} seconds)")
print("--------------------------------------------------")
# Out:
# Epoch 1/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 132s 580ms/step - accuracy: 0.4443 - loss: 2.2524 - val_accuracy: 0.0333 - val_loss: 5.1804
# Epoch 2/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 41s 322ms/step - accuracy: 0.9098 - loss: 0.3498 - val_accuracy: 0.0600 - val_loss: 5.6014
# Epoch 3/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 318ms/step - accuracy: 0.9692 - loss: 0.1400 - val_accuracy: 0.1800 - val_loss: 3.5313
# Epoch 4/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 318ms/step - accuracy: 0.9714 - loss: 0.1029 - val_accuracy: 0.6133 - val_loss: 1.6994
# Epoch 5/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 319ms/step - accuracy: 0.9769 - loss: 0.0989 - val_accuracy: 0.9067 - val_loss: 0.5190
# Epoch 6/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 318ms/step - accuracy: 0.9764 - loss: 0.0707 - val_accuracy: 0.9733 - val_loss: 0.0601
# Epoch 7/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 320ms/step - accuracy: 0.9878 - loss: 0.0562 - val_accuracy: 0.9667 - val_loss: 0.1350
# Epoch 8/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 319ms/step - accuracy: 0.9610 - loss: 0.1314 - val_accuracy: 0.9933 - val_loss: 0.0136
# Epoch 9/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 319ms/step - accuracy: 0.9833 - loss: 0.0566 - val_accuracy: 0.9867 - val_loss: 0.0255
# Epoch 10/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 319ms/step - accuracy: 0.9834 - loss: 0.0503 - val_accuracy: 0.9733 - val_loss: 0.1376
# --------------------------------------------------
# ✅ Training Finished. Model saved to ResNet50.keras
# ⏱️ Total Training Time: 8 minutes and 15 seconds (495.54 seconds)
# --------------------------------------------------

# %% [markdown]
# ## **EfficientNet-B4**

# %%
base = EfficientNetB4(
    weights="imagenet",
    include_top=False,
    input_shape=(Config.IMG_SIZE, Config.IMG_SIZE, 3)
)

inputs = layers.Input((Config.IMG_SIZE, Config.IMG_SIZE, 3))
x = base(inputs, training=True)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(512, activation="relu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = models.Model(inputs, outputs)


model.compile(
    optimizer=tf.keras.optimizers.Adam(Config.LR),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

start_time = time.time()
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=Config.EPOCHS
)
end_time = time.time()
model.save("EfficientNetB4.keras")


# 5. Calculate and Print the Training Time
total_training_time_seconds = end_time - start_time
minutes = int(total_training_time_seconds // 60)
seconds = int(total_training_time_seconds % 60)
print("--------------------------------------------------")
print(f"✅ Training Finished. Model saved to EfficientNetB4.keras")
print(f"⏱️ Total Training Time: {minutes} minutes and {seconds} seconds ({total_training_time_seconds:.2f} seconds)")
print("--------------------------------------------------")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# E0000 00:00:1765884988.310596     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884988.475853     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884997.106596     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884997.249033     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884997.598672     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884997.741204     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884998.134189     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884998.282763     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884998.831834     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884998.985482     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.3150 - loss: 2.7078
# E0000 00:00:1765885097.832827     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885097.986532     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885104.560337     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885104.698457     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885105.014129     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885105.152378     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885105.533740     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885105.677393     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885106.227368     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885106.381021     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - accuracy: 0.3163 - loss: 2.7035
# E0000 00:00:1765885155.318762     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765885155.475065     441 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 260s 998ms/step - accuracy: 0.3177 - loss: 2.6992 - val_accuracy: 0.0667 - val_loss: 3.2181
# Epoch 2/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 48s 376ms/step - accuracy: 0.8788 - loss: 0.6616 - val_accuracy: 0.5200 - val_loss: 1.8685
# Epoch 3/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 47s 371ms/step - accuracy: 0.9599 - loss: 0.2074 - val_accuracy: 0.8667 - val_loss: 0.5016
# Epoch 4/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 47s 373ms/step - accuracy: 0.9791 - loss: 0.1154 - val_accuracy: 0.9933 - val_loss: 0.0529
# Epoch 5/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 47s 371ms/step - accuracy: 0.9784 - loss: 0.0970 - val_accuracy: 0.9667 - val_loss: 0.1092
# Epoch 6/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 47s 373ms/step - accuracy: 0.9814 - loss: 0.0758 - val_accuracy: 1.0000 - val_loss: 0.0151
# Epoch 7/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 47s 373ms/step - accuracy: 0.9890 - loss: 0.0525 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 8/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 47s 373ms/step - accuracy: 0.9961 - loss: 0.0287 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 9/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 47s 374ms/step - accuracy: 0.9913 - loss: 0.0361 - val_accuracy: 0.8733 - val_loss: 0.4042
# Epoch 10/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 47s 373ms/step - accuracy: 0.9930 - loss: 0.0330 - val_accuracy: 0.9867 - val_loss: 0.0484
# --------------------------------------------------
# ✅ Training Finished. Model saved to EfficientNetB4.keras
# ⏱️ Total Training Time: 11 minutes and 24 seconds (684.60 seconds)
# --------------------------------------------------

# %% [markdown]
# ## **ConvNeXT**

# %%
base = ConvNeXtTiny(
    weights="imagenet",
    include_top=False,
    input_shape=(Config.IMG_SIZE, Config.IMG_SIZE, 3)
)

inputs = layers.Input((Config.IMG_SIZE, Config.IMG_SIZE, 3))
x = base(inputs, training=True)
x = layers.GlobalAveragePooling2D()(x)
x = layers.LayerNormalization()(x)
x = layers.Dense(512, activation="gelu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = models.Model(inputs, outputs)


model.compile(
    optimizer=tf.keras.optimizers.Adam(Config.LR),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
start_time = time.time()
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=Config.EPOCHS
)
end_time = time.time()
model.save("ConvNeXtTiny.keras")



total_training_time_seconds = end_time - start_time
minutes = int(total_training_time_seconds // 60)
seconds = int(total_training_time_seconds % 60)
print("--------------------------------------------------")
print(f"✅ Training Finished. Model saved to ConvNeXtTiny.keras")
print(f"⏱️ Total Training Time: {minutes} minutes and {seconds} seconds ({total_training_time_seconds:.2f} seconds)")
print("--------------------------------------------------")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_tiny_notop.h5
# 111650432/111650432 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# E0000 00:00:1765884115.333307     442 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884115.468445     442 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884117.628190     442 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884117.763680     442 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.3077 - loss: 2.6159
# E0000 00:00:1765884210.589284     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884210.724403     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884212.519004     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884212.653649     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - accuracy: 0.3096 - loss: 2.6087
# E0000 00:00:1765884233.390228     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765884233.525361     444 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 152s 813ms/step - accuracy: 0.3115 - loss: 2.6016 - val_accuracy: 0.9067 - val_loss: 0.3754
# Epoch 2/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 74s 584ms/step - accuracy: 0.9432 - loss: 0.2199 - val_accuracy: 0.9667 - val_loss: 0.1361
# Epoch 3/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 73s 578ms/step - accuracy: 0.9778 - loss: 0.0890 - val_accuracy: 1.0000 - val_loss: 0.0383
# Epoch 4/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 73s 577ms/step - accuracy: 0.9756 - loss: 0.0938 - val_accuracy: 0.9733 - val_loss: 0.0763
# Epoch 5/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 73s 580ms/step - accuracy: 0.9837 - loss: 0.0633 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 6/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 73s 580ms/step - accuracy: 0.9919 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 0.0215
# Epoch 7/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 73s 580ms/step - accuracy: 0.9865 - loss: 0.0466 - val_accuracy: 0.9933 - val_loss: 0.0288
# Epoch 8/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 73s 581ms/step - accuracy: 0.9881 - loss: 0.0481 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 9/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 74s 590ms/step - accuracy: 0.9940 - loss: 0.0181 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 10/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 73s 581ms/step - accuracy: 0.9984 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0013
# --------------------------------------------------
# ✅ Training Finished. Model saved to ConvNeXtTiny.keras
# ⏱️ Total Training Time: 13 minutes and 32 seconds (812.68 seconds)
# --------------------------------------------------

# %% [markdown]
# ## **MobileNetV2**

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

IMG_SIZE = Config.IMG_SIZE
NUM_CLASSES = len(class_names) 

base_mobilenet = MobileNetV2(
    weights='imagenet',               
    include_top=False,                 
    input_shape=(IMG_SIZE, IMG_SIZE, 3)  
)

base_mobilenet.trainable = False


inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_mobilenet(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)             
x = layers.Dense(512, activation='relu')(x)
outputs = layers.Dense(NUM_CLASSES, activation='softMax')(x)


model_mobilenet = models.Model(inputs, outputs)


model_mobilenet.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=Config.LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

start_time = time.time()
model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=Config.EPOCHS
)
end_time = time.time()
model.save("MobileNetV2.keras")



total_training_time_seconds = end_time - start_time
minutes = int(total_training_time_seconds // 60)
seconds = int(total_training_time_seconds % 60)
print("--------------------------------------------------")
print(f"✅ Training Finished. Model saved to MobileNetV2.keras")
print(f"⏱️ Total Training Time: {minutes} minutes and {seconds} seconds ({total_training_time_seconds:.2f} seconds)")
print("--------------------------------------------------")
# Out:
# /tmp/ipykernel_47/3321348109.py:7: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_mobilenet = MobileNetV2(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# E0000 00:00:1765912890.336794     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912890.505797     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912902.969360     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912903.111777     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912903.521000     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912903.663837     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912904.073367     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912904.223690     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912904.860818     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765912905.013752     124 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 1.0000 - loss: 0.0048
# E0000 00:00:1765913009.294732     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913009.448474     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913016.326261     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913016.464090     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913016.770335     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913016.908126     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913017.303985     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913017.446520     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913018.012107     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913018.165648     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 894ms/step - accuracy: 1.0000 - loss: 0.0048
# E0000 00:00:1765913064.984819     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765913065.142158     126 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 250s 1s/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 1.5080e-04
# Epoch 2/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 56s 445ms/step - accuracy: 0.9973 - loss: 0.0093 - val_accuracy: 0.9933 - val_loss: 0.0076
# Epoch 3/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 54s 430ms/step - accuracy: 0.9989 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 4/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 433ms/step - accuracy: 0.9979 - loss: 0.0102 - val_accuracy: 0.9533 - val_loss: 0.1988
# Epoch 5/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 435ms/step - accuracy: 0.9984 - loss: 0.0072 - val_accuracy: 0.9800 - val_loss: 0.0716
# Epoch 6/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 434ms/step - accuracy: 0.9985 - loss: 0.0089 - val_accuracy: 0.9867 - val_loss: 0.0231
# Epoch 7/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 434ms/step - accuracy: 0.9983 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 8/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 437ms/step - accuracy: 0.9984 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 3.5521e-04
# Epoch 9/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 435ms/step - accuracy: 0.9971 - loss: 0.0137 - val_accuracy: 0.9800 - val_loss: 0.0634
# Epoch 10/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 55s 436ms/step - accuracy: 0.9976 - loss: 0.0108 - val_accuracy: 0.9400 - val_loss: 0.1867
# --------------------------------------------------
# ✅ Training Finished. Model saved to MobileNetV2.keras
# ⏱️ Total Training Time: 12 minutes and 25 seconds (745.25 seconds)
# --------------------------------------------------

# %% [markdown]
# ## **Custom CNN**

# %%
# ============================================================
# CUSTOM CNN MODEL (FROM SCRATCH) - TENSORFLOW
# ============================================================

import time
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks

# -----------------------------
# MODEL ARCHITECTURE
# -----------------------------
def build_custom_cnn(input_shape, num_classes):
    model = models.Sequential(name="CustomCNN")

    # Block 1
    model.add(layers.Conv2D(32, (3, 3), padding="same", input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    # Block 2
    model.add(layers.Conv2D(64, (3, 3), padding="same"))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    # Block 3
    model.add(layers.Conv2D(128, (3, 3), padding="same"))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    # Block 4
    model.add(layers.Conv2D(256, (3, 3), padding="same"))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    # Classification Head
    model.add(layers.Flatten())
    model.add(layers.Dense(1024, activation="relu"))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(512, activation="relu"))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(num_classes, activation="softmax"))

    return model


# -----------------------------
# BUILD MODEL
# -----------------------------
input_shape = (Config.IMG_SIZE, Config.IMG_SIZE, 3)
num_classes = len(class_names)

custom_cnn = build_custom_cnn(input_shape, num_classes)

custom_cnn.summary()


# -----------------------------
# COMPILE
# -----------------------------
custom_cnn.compile(
    optimizer=tf.keras.optimizers.Adam(Config.LR),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


# -----------------------------
# CALLBACKS
# -----------------------------
custom_callbacks = [
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=10,
        restore_best_weights=True
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_accuracy",
        factor=0.5,
        patience=5,
        verbose=1
    ),
    callbacks.ModelCheckpoint(
        "CustomCNN_best.keras",
        monitor="val_accuracy",
        save_best_only=True,
        verbose=1
    )
]


# -----------------------------
# TRAINING 
# -----------------------------
start_time = time.time()
EPOCHS=30
history_custom = custom_cnn.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=custom_callbacks
)

training_time_custom = time.time() - start_time


# -----------------------------
# FINAL SAVE
# -----------------------------
custom_cnn.save("CustomCNN_final.keras")

print(f"\n⏱ Training Time (Custom CNN): {training_time_custom/60:.2f} minutes")
# Out:
# Model: "CustomCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 350, 350, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 350, 350, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 350, 350, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 175, 175, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 175, 175, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 175, 175, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_9 (ReLU)                  │ (None, 175, 175, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 87, 87, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 87, 87, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 87, 87, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_10 (ReLU)                 │ (None, 87, 87, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 43, 43, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 43, 43, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 43, 43, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_11 (ReLU)                 │ (None, 43, 43, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 21, 21, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 112896)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1024)           │   115,606,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 30)             │        15,390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 116,537,054 (444.55 MB)
#  Trainable params: 116,536,094 (444.55 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.1684 - loss: 8.7664
# Epoch 1: val_accuracy improved from -inf to 0.08667, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 30s 184ms/step - accuracy: 0.1686 - loss: 8.7448 - val_accuracy: 0.0867 - val_loss: 3.1135 - learning_rate: 1.0000e-04
# Epoch 2/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3126 - loss: 2.5818
# Epoch 2: val_accuracy improved from 0.08667 to 0.24000, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 145ms/step - accuracy: 0.3124 - loss: 2.5817 - val_accuracy: 0.2400 - val_loss: 2.7835 - learning_rate: 1.0000e-04
# Epoch 3/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3755 - loss: 2.2393
# Epoch 3: val_accuracy improved from 0.24000 to 0.38667, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 146ms/step - accuracy: 0.3754 - loss: 2.2395 - val_accuracy: 0.3867 - val_loss: 1.8406 - learning_rate: 1.0000e-04
# Epoch 4/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4185 - loss: 2.0229
# Epoch 4: val_accuracy improved from 0.38667 to 0.55333, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 147ms/step - accuracy: 0.4184 - loss: 2.0233 - val_accuracy: 0.5533 - val_loss: 1.5058 - learning_rate: 1.0000e-04
# Epoch 5/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4611 - loss: 1.8967
# Epoch 5: val_accuracy improved from 0.55333 to 0.70667, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 146ms/step - accuracy: 0.4610 - loss: 1.8970 - val_accuracy: 0.7067 - val_loss: 1.1068 - learning_rate: 1.0000e-04
# Epoch 6/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5362 - loss: 1.6307
# Epoch 6: val_accuracy did not improve from 0.70667
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.5359 - loss: 1.6317 - val_accuracy: 0.6533 - val_loss: 1.0454 - learning_rate: 1.0000e-04
# Epoch 7/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5206 - loss: 1.7205
# Epoch 7: val_accuracy improved from 0.70667 to 0.72000, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 0.5205 - loss: 1.7205 - val_accuracy: 0.7200 - val_loss: 1.0134 - learning_rate: 1.0000e-04
# Epoch 8/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5341 - loss: 1.5828
# Epoch 8: val_accuracy improved from 0.72000 to 0.80667, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 0.5341 - loss: 1.5829 - val_accuracy: 0.8067 - val_loss: 0.7366 - learning_rate: 1.0000e-04
# Epoch 9/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5517 - loss: 1.4899
# Epoch 9: val_accuracy did not improve from 0.80667
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.5516 - loss: 1.4901 - val_accuracy: 0.7667 - val_loss: 0.8969 - learning_rate: 1.0000e-04
# Epoch 10/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5965 - loss: 1.3487
# Epoch 10: val_accuracy did not improve from 0.80667
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.5963 - loss: 1.3494 - val_accuracy: 0.7467 - val_loss: 0.8134 - learning_rate: 1.0000e-04
# Epoch 11/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6072 - loss: 1.3647
# Epoch 11: val_accuracy did not improve from 0.80667
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.6070 - loss: 1.3650 - val_accuracy: 0.7800 - val_loss: 0.8287 - learning_rate: 1.0000e-04
# Epoch 12/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5934 - loss: 1.3917
# Epoch 12: val_accuracy did not improve from 0.80667
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.5933 - loss: 1.3920 - val_accuracy: 0.7800 - val_loss: 0.6384 - learning_rate: 1.0000e-04
# Epoch 13/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6089 - loss: 1.3214
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 13: val_accuracy did not improve from 0.80667
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.6088 - loss: 1.3218 - val_accuracy: 0.7933 - val_loss: 0.7660 - learning_rate: 1.0000e-04
# Epoch 14/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6448 - loss: 1.1586
# Epoch 14: val_accuracy improved from 0.80667 to 0.84000, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 0.6448 - loss: 1.1586 - val_accuracy: 0.8400 - val_loss: 0.4596 - learning_rate: 5.0000e-05
# Epoch 15/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6907 - loss: 1.0140
# Epoch 15: val_accuracy did not improve from 0.84000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.6905 - loss: 1.0144 - val_accuracy: 0.7933 - val_loss: 0.5339 - learning_rate: 5.0000e-05
# Epoch 16/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7137 - loss: 0.9370
# Epoch 16: val_accuracy improved from 0.84000 to 0.86000, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 0.7135 - loss: 0.9377 - val_accuracy: 0.8600 - val_loss: 0.5068 - learning_rate: 5.0000e-05
# Epoch 17/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7079 - loss: 0.9313
# Epoch 17: val_accuracy did not improve from 0.86000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7078 - loss: 0.9315 - val_accuracy: 0.8533 - val_loss: 0.4259 - learning_rate: 5.0000e-05
# Epoch 18/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7395 - loss: 0.8597
# Epoch 18: val_accuracy did not improve from 0.86000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.7393 - loss: 0.8605 - val_accuracy: 0.8600 - val_loss: 0.4793 - learning_rate: 5.0000e-05
# Epoch 19/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7102 - loss: 0.9025
# Epoch 19: val_accuracy did not improve from 0.86000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7101 - loss: 0.9027 - val_accuracy: 0.8600 - val_loss: 0.4909 - learning_rate: 5.0000e-05
# Epoch 20/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7280 - loss: 0.8762
# Epoch 20: val_accuracy did not improve from 0.86000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7278 - loss: 0.8765 - val_accuracy: 0.8533 - val_loss: 0.4439 - learning_rate: 5.0000e-05
# Epoch 21/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7265 - loss: 0.9275
# Epoch 21: val_accuracy improved from 0.86000 to 0.87333, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - accuracy: 0.7263 - loss: 0.9279 - val_accuracy: 0.8733 - val_loss: 0.4557 - learning_rate: 5.0000e-05
# Epoch 22/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7643 - loss: 0.7604
# Epoch 22: val_accuracy did not improve from 0.87333
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - accuracy: 0.7641 - loss: 0.7609 - val_accuracy: 0.8533 - val_loss: 0.4723 - learning_rate: 5.0000e-05
# Epoch 23/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7218 - loss: 0.8725
# Epoch 23: val_accuracy improved from 0.87333 to 0.88000, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - accuracy: 0.7217 - loss: 0.8726 - val_accuracy: 0.8800 - val_loss: 0.3659 - learning_rate: 5.0000e-05
# Epoch 24/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7765 - loss: 0.7591
# Epoch 24: val_accuracy did not improve from 0.88000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - accuracy: 0.7763 - loss: 0.7595 - val_accuracy: 0.8600 - val_loss: 0.3801 - learning_rate: 5.0000e-05
# Epoch 25/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7450 - loss: 0.7664
# Epoch 25: val_accuracy improved from 0.88000 to 0.88667, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - accuracy: 0.7450 - loss: 0.7668 - val_accuracy: 0.8867 - val_loss: 0.2938 - learning_rate: 5.0000e-05
# Epoch 26/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7745 - loss: 0.6848
# Epoch 26: val_accuracy did not improve from 0.88667
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7742 - loss: 0.6857 - val_accuracy: 0.8800 - val_loss: 0.4089 - learning_rate: 5.0000e-05
# Epoch 27/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7555 - loss: 0.8070
# Epoch 27: val_accuracy did not improve from 0.88667
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7554 - loss: 0.8072 - val_accuracy: 0.8733 - val_loss: 0.4336 - learning_rate: 5.0000e-05
# Epoch 28/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7704 - loss: 0.7403
# Epoch 28: val_accuracy improved from 0.88667 to 0.93333, saving model to CustomCNN_best.keras
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 174ms/step - accuracy: 0.7702 - loss: 0.7410 - val_accuracy: 0.9333 - val_loss: 0.2889 - learning_rate: 5.0000e-05
# Epoch 29/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7660 - loss: 0.8042
# Epoch 29: val_accuracy did not improve from 0.93333
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7659 - loss: 0.8041 - val_accuracy: 0.8867 - val_loss: 0.3651 - learning_rate: 5.0000e-05
# Epoch 30/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7728 - loss: 0.6478
# Epoch 30: val_accuracy did not improve from 0.93333
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.7727 - loss: 0.6482 - val_accuracy: 0.9267 - val_loss: 0.2911 - learning_rate: 5.0000e-05
#
# ⏱ Training Time (Custom CNN): 7.71 minutes

# %% [markdown]
# # ***Prepared By Team 3***
